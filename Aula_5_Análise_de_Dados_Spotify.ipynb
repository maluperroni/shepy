# %% [markdown]
# <a href="https://colab.research.google.com/github/maluperroni/shepy/blob/main/Aula_5_An%C3%A1lise_de_Dados_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Análise e visualização de dados do Spotify
# ![spotify](https://mms.businesswire.com/media/20210201006022/pt/856118/23/Spotify_Logo_RGB_Green.jpg)
#
# Dados obtidos em: https://www.kaggle.com/leonardopena/top50spotify2019

# %% [markdown]
# ### O que é um DataFrame?
# Um dataframe é uma estrutura de dados bidimensional, onde os dados são alinhados de forma tabular em linhas e colunas.

# %%
import pandas as pd

# %%
df = pd.read_csv('top50.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Unnamed: 0                       Track.Name  ... Speechiness. Popularity
# 0           1                         Señorita  ...            3         79
# 1           2                            China  ...            9         92
# 2           3    boyfriend (with Social House)  ...           46         85
# 3           4  Beautiful People (feat. Khalid)  ...           19         86
# 4           5      Goodbyes (Feat. Young Thug)  ...            7         94
#
# [5 rows x 14 columns]

# %% [markdown]
# ##Alterando o dataframe para facilitar as análises

# %%
df.drop('Unnamed: 0', axis=1, inplace=True) #usando o unnamed:0 para apagar a primeira coluna, o inplace=true para subscrever o dataframe original e axis=1 para modificar a coluna.

# %%
df.rename(columns={'Track.Name':'Track',
                   'Artist.Name':'Artist',
                   'Genre':'Genre',
                   'Beats.Per.Minute':'Bpm',
                   'Energy':'Energy',
                   'Danceability':'Danceability',
                   'Loudness..dB..':'Loudness',
                   'Liveness':'Liveness',
                   'Valence.':'Valence',
                   'Length.':'Length',
                   'Acousticness..':'Acousticness',
                   'Speechiness.':'Speechiness',
                   'Popularity':'Popularity'}, inplace=True)

# %%
df.head() #o head permite visualizar as 5 primeiras linhas
# Out:
#                              Track         Artist  ... Speechiness  Popularity
# 0                         Señorita   Shawn Mendes  ...           3          79
# 1                            China       Anuel AA  ...           9          92
# 2    boyfriend (with Social House)  Ariana Grande  ...          46          85
# 3  Beautiful People (feat. Khalid)     Ed Sheeran  ...          19          86
# 4      Goodbyes (Feat. Young Thug)    Post Malone  ...           7          94
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Análise exploratória dos dados

# %%
df.shape #comando que permite ver quantas linhas e colunas tem o dataframe
# Out:
# (50, 13)

# %%
df.describe()
# Out:
#               Bpm     Energy  ...  Speechiness  Popularity
# count   50.000000  50.000000  ...    50.000000   50.000000
# mean   120.060000  64.060000  ...    12.480000   87.500000
# std     30.898392  14.231913  ...    11.161596    4.491489
# min     85.000000  32.000000  ...     3.000000   70.000000
# 25%     96.000000  55.250000  ...     5.000000   86.000000
# 50%    104.500000  66.500000  ...     7.000000   88.000000
# 75%    137.500000  74.750000  ...    15.000000   90.750000
# max    190.000000  88.000000  ...    46.000000   95.000000
#
# [8 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Track         50 non-null     object
#  1   Artist        50 non-null     object
#  2   Genre         50 non-null     object
#  3   Bpm           50 non-null     int64
#  4   Energy        50 non-null     int64
#  5   Danceability  50 non-null     int64
#  6   Loudness      50 non-null     int64
#  7   Liveness      50 non-null     int64
#  8   Valence       50 non-null     int64
#  9   Length        50 non-null     int64
#  10  Acousticness  50 non-null     int64
#  11  Speechiness   50 non-null     int64
#  12  Popularity    50 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 5.2+ KB

# %% [markdown]
# ###**Analisando dados de gêneros musicais**

# %%
df['Genre'].unique() #mostrar quais os tipos de gênero musicais aparecem, o unique solicita que apareça apenas um de cada
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
df['Genre'].nunique() #solicitando a quantidade de gêneros
# Out:
# 21

# %%
df['Genre'].value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# edm                 3
# canadian hip hop    3
# panamanian pop      2
# reggaeton           2
# canadian pop        2
# country rap         2
# electropop          2
# brostep             2
# dfw rap             2
# reggaeton flow      2
# escape room         1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# trap music          1
# r&b en espanol      1
# pop house           1
# Name: Genre, dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.figure(figsize=(7,5)) #ajustando o tamanho do gráfico

sns.countplot(y='Genre',
              data=df,
              palette='Greens_d',
              order=df['Genre'].value_counts().index).set_title('Gêneros Músicais')
# Out:
# Text(0.5, 1.0, 'Gêneros Músicais')

# %% [markdown]
# **Analisando dados de Batidas por Minuto (Bpm)**

# %%
print(df['Bpm'].min(), df['Bpm'].max()) #valores mínimos e máximos de bpm
# Out:
# 85 190

# %%
plt.figure(figsize=(8,4))  
sns.distplot(df['Bpm'], bins=20, color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Filtrando os dados:

# %%
df.query('Bpm==190')
# Out:
#                            Track         Artist  ... Speechiness  Popularity
# 2  boyfriend (with Social House)  Ariana Grande  ...          46          85
#
# [1 rows x 13 columns]

# %%
df.query('Bpm==85')
# Out:
#                     Track            Artist  ... Speechiness  Popularity
# 30               Takeaway  The Chainsmokers  ...           4          84
# 41  You Need To Calm Down      Taylor Swift  ...           5          90
#
# [2 rows x 13 columns]

# %%
df.query('Bpm >= 170 and Energy >= 60')
# Out:
#                             Track         Artist  ... Speechiness  Popularity
# 2   boyfriend (with Social House)  Ariana Grande  ...          46          85
# 6                          Ransom      Lil Tecca  ...          29          92
# 10                       Callaita      Bad Bunny  ...          31          93
# 13             Otro Trago - Remix           Sech  ...          20          87
# 16                     LA CANCIÓN       J Balvin  ...          32          90
# 36                     Otro Trago           Sech  ...          34          91
# 46                      Te Robaré      Nicky Jam  ...           6          88
#
# [7 rows x 13 columns]

# %% [markdown]
# **Analisando dados de popularidade**

# %%
df.query('Popularity == 95') #música mais popular
# Out:
#      Track         Artist       Genre  ...  Acousticness  Speechiness  Popularity
# 9  bad guy  Billie Eilish  electropop  ...            33           38          95
#
# [1 rows x 13 columns]

# %%
plt.figure(figsize=(12,8)) #com o plt fornece suporte para as outras libs

sns.boxplot(x='Popularity', y='Genre', data=df, palette = 'Set1') #o sns faz o "grosso" do trabalho, gerando a análise dos dados

plt.xlabel('Popularidade', fontsize=16)
plt.ylabel('Gênero', fontsize=16)
plt.yticks(rotation='0')
plt.title("Gênero vs popularidade", fontsize=20)
plt.show()

# %%
#gerando um dataframe apenas com músicas com popularidade maior ou igual a 90
most_popular = df.query('Popularity >= 90') 
len(most_popular)
# Out:
# 16

# %%
plt.figure(figsize=(8,5))

sns.countplot(y='Genre',
              data=most_popular,
              palette='rocket',
              order=most_popular['Genre'].value_counts().index).set_title("Gêneros musicais das 16 músicas mais populares")
# Out:
# Text(0.5, 1.0, 'Gêneros musicais das 16 músicas mais populares')

# %% [markdown]
# **Correlação**
#
# Um coeficiente de correlação é uma medida numérica de algum tipo de correlação, significando uma relação estatística entre duas variáveis. O coeficiente de correlação assume valores na faixa de -1 a +1, em que +1 indica forte correlação positiva, -1 forte correlação negativa e 0 uma situação onde não há correlação entre as variáveis.

# %%
df.head(3)
# Out:
#                            Track         Artist  ... Speechiness  Popularity
# 0                       Señorita   Shawn Mendes  ...           3          79
# 1                          China       Anuel AA  ...           9          92
# 2  boyfriend (with Social House)  Ariana Grande  ...          46          85
#
# [3 rows x 13 columns]

# %%
#Analisando correlação apenas das colunas de dados numéricos
corr = df.loc[:, 'Bpm': 'Popularity'].corr()
corr
# Out:
#                    Bpm    Energy  ...  Speechiness  Popularity
# Bpm           1.000000  0.043756  ...     0.557052    0.196097
# Energy        0.043756  1.000000  ...    -0.089860   -0.080295
# Danceability -0.094183  0.018254  ...    -0.103472   -0.071413
# Loudness      0.017016  0.670794  ...    -0.272213   -0.043085
# Liveness     -0.167286  0.162768  ...    -0.125286    0.092564
# Valence      -0.011586  0.438820  ...    -0.053242   -0.317752
# Length       -0.139288  0.224677  ...     0.046755   -0.087639
# Acousticness -0.031450 -0.339892  ...     0.008293   -0.034684
# Speechiness   0.557052 -0.089860  ...     1.000000    0.238553
# Popularity    0.196097 -0.080295  ...     0.238553    1.000000
#
# [10 rows x 10 columns]

# %%
plt.figure(figsize=(12, 6))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, cmap=cmap, center=0, vmin=-1, vmax=1, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})  # função que permite criar uma matriz retangular ordenada por cores

# %% [markdown]
# **Nuvem de palavras:**

# %%
from wordcloud import WordCloud
from collections import Counter
allSongs = [trackname for trackname in df['Artist']]
wc_dict = Counter(allSongs)

wordcloud = WordCloud(width=700, height=400, background_color = 'white').generate_from_frequencies(wc_dict)
plt.figure(figsize = (15, 10))
plt.imshow(wordcloud)
plt.axis('off');

# %% [markdown]
# Para saber mais:
# - https://seaborn.pydata.org/tutorial/color_palettes.html
# - https://seaborn.pydata.org/generated/seaborn.countplot.html
# - https://matplotlib.org/
